# %%
import pandas as pd
from pandas.io.excel import ExcelFile

# %%
infile = ExcelFile('ColorBrewer_all_schemes_RGBonly3.XLS')

# %%
df = infile.parse(infile.sheet_names[0])

# %%
df_fill = df.fillna(method = 'ffill')

# %%
df_fill.head()
# Out:
#   ColorName  NumOfColors  Type  CritVal  ColorNum ColorLetter    R    G    B  \
# 0    Accent            3  qual      NaN         1           A  127  201  127
# 1    Accent            3  qual      NaN         2           B  190  174  212
# 2    Accent            3  qual      NaN         3           C  253  192  134
# 3    Accent            4  qual      NaN         1           A  127  201  127
# 4    Accent            4  qual      NaN         2           B  190  174  212
#
#     SchemeType
# 0  Qualitative
# 1  Qualitative
# 2  Qualitative
# 3  Qualitative
# 4  Qualitative

# %%
df.head()
# Out:
#   ColorName  NumOfColors  Type  CritVal  ColorNum ColorLetter    R    G    B  \
# 0    Accent            3  qual      NaN         1           A  127  201  127
# 1       NaN          NaN   NaN      NaN         2           B  190  174  212
# 2       NaN          NaN   NaN      NaN         3           C  253  192  134
# 3    Accent            4  qual      NaN         1           A  127  201  127
# 4       NaN          NaN   NaN      NaN         2           B  190  174  212
#
#     SchemeType
# 0  Qualitative
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#df_key = pd.factorize(pd.lib.fast_zip([df_fill.ColorName, df_fill.NumOfColors]))

# %%
#df_key[0]

# %%
#df_fill.index = df_key[0]

# %%
df_fill.head(40)
# Out:
#    ColorName  NumOfColors  Type  CritVal  ColorNum ColorLetter    R    G    B  \
# 0     Accent            3  qual      NaN         1           A  127  201  127
# 1     Accent            3  qual      NaN         2           B  190  174  212
# 2     Accent            3  qual      NaN         3           C  253  192  134
# 3     Accent            4  qual      NaN         1           A  127  201  127
# 4     Accent            4  qual      NaN         2           B  190  174  212
# 5     Accent            4  qual      NaN         3           C  253  192  134
# 6     Accent            4  qual      NaN         4           D  255  255  153
# 7     Accent            5  qual      NaN         1           A  127  201  127
# 8     Accent            5  qual      NaN         2           B  190  174  212
# 9     Accent            5  qual      NaN         3           C  253  192  134
# 10    Accent            5  qual      NaN         4           D  255  255  153
# 11    Accent            5  qual      NaN         5           E   56  108  176
# 12    Accent            6  qual      NaN         1           A  127  201  127
# 13    Accent            6  qual      NaN         2           B  190  174  212
# 14    Accent            6  qual      NaN         3           C  253  192  134
# 15    Accent            6  qual      NaN         4           D  255  255  153
# 16    Accent            6  qual      NaN         5           E   56  108  176
# 17    Accent            6  qual      NaN         6           F  240    2  127
# 18    Accent            7  qual      NaN         1           A  127  201  127
# 19    Accent            7  qual      NaN         2           B  190  174  212
# 20    Accent            7  qual      NaN         3           C  253  192  134
# 21    Accent            7  qual      NaN         4           D  255  255  153
# 22    Accent            7  qual      NaN         5           E   56  108  176
# 23    Accent            7  qual      NaN         6           F  240    2  127
# 24    Accent            7  qual      NaN         7           G  191   91   23
# 25    Accent            8  qual      NaN         1           A  127  201  127
# 26    Accent            8  qual      NaN         2           B  190  174  212
# 27    Accent            8  qual      NaN         3           C  253  192  134
# 28    Accent            8  qual      NaN         4           D  255  255  153
# 29    Accent            8  qual      NaN         5           E   56  108  176
# 30    Accent            8  qual      NaN         6           F  240    2  127
# 31    Accent            8  qual      NaN         7           G  191   91   23
# 32    Accent            8  qual      NaN         8           H  102  102  102
# 33     Blues            3   seq      NaN         1           C  222  235  247
# 34     Blues            3   seq      NaN         2           F  158  202  225
# 35     Blues            3   seq      NaN         3           I   49  130  189
# 36     Blues            4   seq      NaN         1           B  239  243  255
# 37     Blues            4   seq      NaN         2           E  189  215  231
# 38     Blues            4   seq      NaN         3           G  107  174  214
# 39     Blues            4   seq      NaN         4           J   33  113  181
#
#      SchemeType
# 0   Qualitative
# 1   Qualitative
# 2   Qualitative
# 3   Qualitative
# 4   Qualitative
# 5   Qualitative
# 6   Qualitative
# 7   Qualitative
# 8   Qualitative
# 9   Qualitative
# 10  Qualitative
# 11  Qualitative
# 12  Qualitative
# 13  Qualitative
# 14  Qualitative
# 15  Qualitative
# 16  Qualitative
# 17  Qualitative
# 18  Qualitative
# 19  Qualitative
# 20  Qualitative
# 21  Qualitative
# 22  Qualitative
# 23  Qualitative
# 24  Qualitative
# 25  Qualitative
# 26  Qualitative
# 27  Qualitative
# 28  Qualitative
# 29  Qualitative
# 30  Qualitative
# 31  Qualitative
# 32  Qualitative
# 33   Sequential
# 34   Sequential
# 35   Sequential
# 36   Sequential
# 37   Sequential
# 38   Sequential
# 39   Sequential

# %%
df_fill.to_excel('ColorBrewer_all_schemes_RGBonly3_updated.XLS', sheet_name = 'Sheet1')

# %%
df_fill.to_csv('ColorBrewer_all_schemes_RGBonly3_updated.csv')
