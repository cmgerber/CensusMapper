# %%
import pandas as pd
from pandas.io.excel import ExcelFile

# %%
infile = ExcelFile('ColorBrewer_all_schemes_RGBonly3.XLS')

# %%
df = infile.parse(infile.sheet_names[0])

# %%
df_fill = df.fillna(method = 'ffill')

# %%
df_fill.head()
# Out:
#   ColorName  NumOfColors  Type  CritVal  ColorNum ColorLetter    R    G    B  \
# 0    Accent            3  qual      NaN         1           A  127  201  127
# 1    Accent            3  qual      NaN         2           B  190  174  212
# 2    Accent            3  qual      NaN         3           C  253  192  134
# 3    Accent            4  qual      NaN         1           A  127  201  127
# 4    Accent            4  qual      NaN         2           B  190  174  212
#
#     SchemeType
# 0  Qualitative
# 1  Qualitative
# 2  Qualitative
# 3  Qualitative
# 4  Qualitative

# %%
df_fill = df_fill.drop(['Type', 'ColorNum'], axis = 1)

# %%
df_fill.head()
# Out:
#   ColorName  NumOfColors  CritVal ColorLetter    R    G    B   SchemeType
# 0    Accent            3      NaN           A  127  201  127  Qualitative
# 1    Accent            3      NaN           B  190  174  212  Qualitative
# 2    Accent            3      NaN           C  253  192  134  Qualitative
# 3    Accent            4      NaN           A  127  201  127  Qualitative
# 4    Accent            4      NaN           B  190  174  212  Qualitative

# %%
#df_key = pd.factorize(pd.lib.fast_zip([df_fill.ColorName, df_fill.NumOfColors]))

# %%
#df_key[0]

# %%
#df_fill.index = df_key[0]

# %%
df_fill.head(40)
# Out:
#    ColorName  NumOfColors  CritVal ColorLetter    R    G    B   SchemeType
# 0     Accent            3      NaN           A  127  201  127  Qualitative
# 1     Accent            3      NaN           B  190  174  212  Qualitative
# 2     Accent            3      NaN           C  253  192  134  Qualitative
# 3     Accent            4      NaN           A  127  201  127  Qualitative
# 4     Accent            4      NaN           B  190  174  212  Qualitative
# 5     Accent            4      NaN           C  253  192  134  Qualitative
# 6     Accent            4      NaN           D  255  255  153  Qualitative
# 7     Accent            5      NaN           A  127  201  127  Qualitative
# 8     Accent            5      NaN           B  190  174  212  Qualitative
# 9     Accent            5      NaN           C  253  192  134  Qualitative
# 10    Accent            5      NaN           D  255  255  153  Qualitative
# 11    Accent            5      NaN           E   56  108  176  Qualitative
# 12    Accent            6      NaN           A  127  201  127  Qualitative
# 13    Accent            6      NaN           B  190  174  212  Qualitative
# 14    Accent            6      NaN           C  253  192  134  Qualitative
# 15    Accent            6      NaN           D  255  255  153  Qualitative
# 16    Accent            6      NaN           E   56  108  176  Qualitative
# 17    Accent            6      NaN           F  240    2  127  Qualitative
# 18    Accent            7      NaN           A  127  201  127  Qualitative
# 19    Accent            7      NaN           B  190  174  212  Qualitative
# 20    Accent            7      NaN           C  253  192  134  Qualitative
# 21    Accent            7      NaN           D  255  255  153  Qualitative
# 22    Accent            7      NaN           E   56  108  176  Qualitative
# 23    Accent            7      NaN           F  240    2  127  Qualitative
# 24    Accent            7      NaN           G  191   91   23  Qualitative
# 25    Accent            8      NaN           A  127  201  127  Qualitative
# 26    Accent            8      NaN           B  190  174  212  Qualitative
# 27    Accent            8      NaN           C  253  192  134  Qualitative
# 28    Accent            8      NaN           D  255  255  153  Qualitative
# 29    Accent            8      NaN           E   56  108  176  Qualitative
# 30    Accent            8      NaN           F  240    2  127  Qualitative
# 31    Accent            8      NaN           G  191   91   23  Qualitative
# 32    Accent            8      NaN           H  102  102  102  Qualitative
# 33     Blues            3      NaN           C  222  235  247   Sequential
# 34     Blues            3      NaN           F  158  202  225   Sequential
# 35     Blues            3      NaN           I   49  130  189   Sequential
# 36     Blues            4      NaN           B  239  243  255   Sequential
# 37     Blues            4      NaN           E  189  215  231   Sequential
# 38     Blues            4      NaN           G  107  174  214   Sequential
# 39     Blues            4      NaN           J   33  113  181   Sequential

# %%
df_fill.to_excel('ColorBrewer_all_schemes_RGBonly3_updated.XLS', sheet_name = 'Sheet1')

# %%
df_fill.to_csv('ColorBrewer_all_schemes_RGBonly3_updated.csv', header = False)

# %%
test_in = pd.read_csv('ColorBrewer_all_schemes_RGBonly3_updated.csv')

# %%
test_in.head(30)
# Out:
#      0  Accent  3.0  Unnamed: 3  A  127.0  201.0  127.0.1  Qualitative
# 0    1  Accent    3         NaN  B    190    174      212  Qualitative
# 1    2  Accent    3         NaN  C    253    192      134  Qualitative
# 2    3  Accent    4         NaN  A    127    201      127  Qualitative
# 3    4  Accent    4         NaN  B    190    174      212  Qualitative
# 4    5  Accent    4         NaN  C    253    192      134  Qualitative
# 5    6  Accent    4         NaN  D    255    255      153  Qualitative
# 6    7  Accent    5         NaN  A    127    201      127  Qualitative
# 7    8  Accent    5         NaN  B    190    174      212  Qualitative
# 8    9  Accent    5         NaN  C    253    192      134  Qualitative
# 9   10  Accent    5         NaN  D    255    255      153  Qualitative
# 10  11  Accent    5         NaN  E     56    108      176  Qualitative
# 11  12  Accent    6         NaN  A    127    201      127  Qualitative
# 12  13  Accent    6         NaN  B    190    174      212  Qualitative
# 13  14  Accent    6         NaN  C    253    192      134  Qualitative
# 14  15  Accent    6         NaN  D    255    255      153  Qualitative
# 15  16  Accent    6         NaN  E     56    108      176  Qualitative
# 16  17  Accent    6         NaN  F    240      2      127  Qualitative
# 17  18  Accent    7         NaN  A    127    201      127  Qualitative
# 18  19  Accent    7         NaN  B    190    174      212  Qualitative
# 19  20  Accent    7         NaN  C    253    192      134  Qualitative
# 20  21  Accent    7         NaN  D    255    255      153  Qualitative
# 21  22  Accent    7         NaN  E     56    108      176  Qualitative
# 22  23  Accent    7         NaN  F    240      2      127  Qualitative
# 23  24  Accent    7         NaN  G    191     91       23  Qualitative
# 24  25  Accent    8         NaN  A    127    201      127  Qualitative
# 25  26  Accent    8         NaN  B    190    174      212  Qualitative
# 26  27  Accent    8         NaN  C    253    192      134  Qualitative
# 27  28  Accent    8         NaN  D    255    255      153  Qualitative
# 28  29  Accent    8         NaN  E     56    108      176  Qualitative
# 29  30  Accent    8         NaN  F    240      2      127  Qualitative
